# %% [markdown]
# ### Exercise 1
#
# - create variables a, c and d with respective types float, int and str

# %% [markdown]
# ### Exercise 2
#
# - create variables e, f and g with respective values 2.5, 2 and 'hello'

# %% [markdown]
# ### Exercise 3
#
# - verify a and e, c and f, c and g have the same types using the *type()* fonction: use the == operator to assess equality
# - example: *type(a) == type(e)*
